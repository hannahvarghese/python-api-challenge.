# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 579

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        #city_dict={}
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #print(city_weather)

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        #city_dict['Latitude']=city_lat
        #city_dict['Longitude']=city_lng
        #city_dict['Max Temp']=city_max_temp
        #city_dict['Humidity']=city_humidity
        #city_dict['Clouds']=city_clouds
        #city_dict['Wind']=city_wind
        #city_dict['Country']=city_country
        #city_dict['Date']= city_date
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

            
# If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ilulissat
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | st. john's
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | boguchany
# Processing Record 6 of Set 1 | iskateley
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | i-n-salah
# Processing Record 9 of Set 1 | olonkinbyen
# Processing Record 10 of Set 1 | winslow
# Processing Record 11 of Set 1 | val-d'or
# Processing Record 12 of Set 1 | badger
# Processing Record 13 of Set 1 | hamilton
# Processing Record 14 of Set 1 | okha
# Processing Record 15 of Set 1 | qaqortoq
# Processing Record 16 of Set 1 | namtsy
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | arteche
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | puerto natales
# Processing Record 21 of Set 1 | iqaluit
# Processing Record 22 of Set 1 | west island
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | san antonio de pale
# Processing Record 26 of Set 1 | paide
# Processing Record 27 of Set 1 | vila velha
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | wailea
# Processing Record 30 of Set 1 | izyum
# Processing Record 31 of Set 1 | kingston
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | zapopan
# Processing Record 34 of Set 1 | wajir
# Processing Record 35 of Set 1 | howard springs
# Processing Record 36 of Set 1 | anadyr
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | luganville
# Processing Record 39 of Set 1 | kaya
# Processing Record 40 of Set 1 | college
# Processing Record 41 of Set 1 | weiser
# Processing Record 42 of Set 1 | utrik
# Processing Record 43 of Set 1 | yuzhno-kurilsk
# Processing Record 44 of Set 1 | tarko-sale
# Processing Record 45 of Set 1 | kapuskasing
# Processing Record 46 of Set 1 | kandyagash
# Processing Record 47 of Set 1 | bamboo flat
# Processing Record 48 of Set 1 | viedma
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | grand falls-windsor
# Processing Record 0 of Set 2 | nicoya
# Processing Record 1 of Set 2 | alice springs
# Processing Record 2 of Set 2 | dwarka
# Processing Record 3 of Set 2 | atafu village
# Processing Record 4 of Set 2 | new plymouth
# Processing Record 5 of Set 2 | bomadi
# Processing Record 6 of Set 2 | tromso
# Processing Record 7 of Set 2 | guerrero negro
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | akureyri
# Processing Record 10 of Set 2 | lihue
# Processing Record 11 of Set 2 | natal
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | port mathurin
# Processing Record 14 of Set 2 | shangri-la
# City not found. Skipping...
# Processing Record 15 of Set 2 | major isidoro
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | san-pedro
# Processing Record 18 of Set 2 | zhangatas
# Processing Record 19 of Set 2 | bonthe
# Processing Record 20 of Set 2 | wailua homesteads
# Processing Record 21 of Set 2 | altay
# Processing Record 22 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 2 | thunder bay
# Processing Record 24 of Set 2 | laguna
# Processing Record 25 of Set 2 | dudinka
# Processing Record 26 of Set 2 | oranjemund
# Processing Record 27 of Set 2 | lazaro cardenas
# Processing Record 28 of Set 2 | la'ie
# Processing Record 29 of Set 2 | puerto ayacucho
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | hawaiian paradise park
# Processing Record 33 of Set 2 | caleta de carquin
# Processing Record 34 of Set 2 | la ronge
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | belyy yar
# Processing Record 37 of Set 2 | peniche
# Processing Record 38 of Set 2 | whitehorse
# Processing Record 39 of Set 2 | edinburgh of the seven seas
# Processing Record 40 of Set 2 | talnakh
# Processing Record 41 of Set 2 | pacasmayo
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | brisas de zicatela
# Processing Record 44 of Set 2 | den burg
# Processing Record 45 of Set 2 | island harbour
# Processing Record 46 of Set 2 | tanjung pandan
# Processing Record 47 of Set 2 | abepura
# Processing Record 48 of Set 2 | touros
# Processing Record 49 of Set 2 | papatowai
# Processing Record 0 of Set 3 | bredasdorp
# Processing Record 1 of Set 3 | carahue
# Processing Record 2 of Set 3 | stanley
# Processing Record 3 of Set 3 | beteza
# City not found. Skipping...
# Processing Record 4 of Set 3 | constantia
# Processing Record 5 of Set 3 | arawa
# Processing Record 6 of Set 3 | polyarnyy
# Processing Record 7 of Set 3 | zhangye
# Processing Record 8 of Set 3 | bay roberts
# Processing Record 9 of Set 3 | nova sintra
# Processing Record 10 of Set 3 | keflavik
# Processing Record 11 of Set 3 | uturoa
# Processing Record 12 of Set 3 | krutinka
# Processing Record 13 of Set 3 | toba
# Processing Record 14 of Set 3 | argo
# Processing Record 15 of Set 3 | palangkaraya
# Processing Record 16 of Set 3 | tokar
# Processing Record 17 of Set 3 | mejit
# Processing Record 18 of Set 3 | isafjordur
# Processing Record 19 of Set 3 | aasiaat
# Processing Record 20 of Set 3 | naliya
# Processing Record 21 of Set 3 | daugavpils
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | celestun
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | namie
# Processing Record 28 of Set 3 | margaret river
# Processing Record 29 of Set 3 | remire-montjoly
# Processing Record 30 of Set 3 | ambovombe
# Processing Record 31 of Set 3 | sinabang
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | garissa
# Processing Record 34 of Set 3 | blackmans bay
# Processing Record 35 of Set 3 | tazacorte
# Processing Record 36 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 3 | borzya
# Processing Record 38 of Set 3 | lukolela
# Processing Record 39 of Set 3 | enewetak
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | okondja
# Processing Record 42 of Set 3 | port lincoln
# Processing Record 43 of Set 3 | warman
# Processing Record 44 of Set 3 | pulgaon
# Processing Record 45 of Set 3 | avanigadda
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | rikaze
# Processing Record 48 of Set 3 | reggane
# Processing Record 49 of Set 3 | shingu
# Processing Record 0 of Set 4 | suva
# Processing Record 1 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | masterton
# Processing Record 4 of Set 4 | yanykurgan
# Processing Record 5 of Set 4 | el sauzal de rodriguez
# Processing Record 6 of Set 4 | wick
# Processing Record 7 of Set 4 | nogliki
# Processing Record 8 of Set 4 | palmer
# Processing Record 9 of Set 4 | aksaray
# Processing Record 10 of Set 4 | pariaman
# Processing Record 11 of Set 4 | el dorado
# Processing Record 12 of Set 4 | vorgashor
# Processing Record 13 of Set 4 | palikir - national government center
# Processing Record 14 of Set 4 | colonia
# Processing Record 15 of Set 4 | minas de marcona
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | rio grande
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | hermanus
# Processing Record 20 of Set 4 | saipan
# Processing Record 21 of Set 4 | porbandar
# Processing Record 22 of Set 4 | kindu
# Processing Record 23 of Set 4 | new amsterdam
# Processing Record 24 of Set 4 | taltal
# Processing Record 25 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 4 | bani walid
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | ndofane
# Processing Record 29 of Set 4 | hilo
# Processing Record 30 of Set 4 | sao joao da barra
# Processing Record 31 of Set 4 | sunrise manor
# Processing Record 32 of Set 4 | tambacounda
# Processing Record 33 of Set 4 | terekeka
# City not found. Skipping...
# Processing Record 34 of Set 4 | horta
# Processing Record 35 of Set 4 | antofagasta
# Processing Record 36 of Set 4 | kavalerovo
# Processing Record 37 of Set 4 | mpumalanga
# Processing Record 38 of Set 4 | kununurra
# Processing Record 39 of Set 4 | mount isa
# Processing Record 40 of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 41 of Set 4 | namibe
# Processing Record 42 of Set 4 | broken hill
# Processing Record 43 of Set 4 | miquelon
# Processing Record 44 of Set 4 | prince albert
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | nuuk
# Processing Record 47 of Set 4 | ulladulla
# Processing Record 48 of Set 4 | meulaboh
# Processing Record 49 of Set 4 | tinghir
# Processing Record 0 of Set 5 | birjand
# Processing Record 1 of Set 5 | ciudad general teran
# Processing Record 2 of Set 5 | ola
# Processing Record 3 of Set 5 | piti village
# Processing Record 4 of Set 5 | yuksekova
# Processing Record 5 of Set 5 | chonchi
# Processing Record 6 of Set 5 | daru
# Processing Record 7 of Set 5 | santo antonio
# Processing Record 8 of Set 5 | port shepstone
# Processing Record 9 of Set 5 | serik
# Processing Record 10 of Set 5 | besikduzu
# Processing Record 11 of Set 5 | newman
# Processing Record 12 of Set 5 | cartagena del chaira
# Processing Record 13 of Set 5 | qamdo
# Processing Record 14 of Set 5 | afaahiti
# Processing Record 15 of Set 5 | jinchang
# Processing Record 16 of Set 5 | nar'yan-mar
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | cabo san lucas
# Processing Record 19 of Set 5 | pantai cenang
# City not found. Skipping...
# Processing Record 20 of Set 5 | marka
# Processing Record 21 of Set 5 | al jawf
# Processing Record 22 of Set 5 | nouadhibou
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | fonte boa
# Processing Record 25 of Set 5 | kupang
# Processing Record 26 of Set 5 | pemba
# Processing Record 27 of Set 5 | axim
# Processing Record 28 of Set 5 | klyuchi
# Processing Record 29 of Set 5 | sarmiento
# Processing Record 30 of Set 5 | kindia
# Processing Record 31 of Set 5 | paradera
# City not found. Skipping...
# Processing Record 32 of Set 5 | palapye
# Processing Record 33 of Set 5 | kayyerkan
# Processing Record 34 of Set 5 | goundam
# Processing Record 35 of Set 5 | weno
# Processing Record 36 of Set 5 | anabar
# City not found. Skipping...
# Processing Record 37 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 38 of Set 5 | marco island
# Processing Record 39 of Set 5 | amga
# Processing Record 40 of Set 5 | dalcahue
# Processing Record 41 of Set 5 | wangkui
# Processing Record 42 of Set 5 | gobabis
# Processing Record 43 of Set 5 | howrah
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | acajutla
# Processing Record 46 of Set 5 | fangshan
# Processing Record 47 of Set 5 | san patricio
# Processing Record 48 of Set 5 | mariental
# Processing Record 49 of Set 5 | vallenar
# Processing Record 0 of Set 6 | gumla
# Processing Record 1 of Set 6 | vrangel'
# Processing Record 2 of Set 6 | ishinomaki
# Processing Record 3 of Set 6 | port-vila
# Processing Record 4 of Set 6 | rongelap
# Processing Record 5 of Set 6 | east london
# Processing Record 6 of Set 6 | jackson
# Processing Record 7 of Set 6 | benghazi
# Processing Record 8 of Set 6 | arno
# Processing Record 9 of Set 6 | wuwei
# Processing Record 10 of Set 6 | arraial do cabo
# Processing Record 11 of Set 6 | mkushi
# Processing Record 12 of Set 6 | tshikapa
# Processing Record 13 of Set 6 | isola di capo rizzuto
# Processing Record 14 of Set 6 | mudanya
# Processing Record 15 of Set 6 | ranau
# Processing Record 16 of Set 6 | rio verde de mato grosso
# Processing Record 17 of Set 6 | oliena
# Processing Record 18 of Set 6 | lerwick
# Processing Record 19 of Set 6 | kibaha
# Processing Record 20 of Set 6 | kuala belait
# Processing Record 21 of Set 6 | xining
# Processing Record 22 of Set 6 | torghay
# Processing Record 23 of Set 6 | nizhneangarsk
# Processing Record 24 of Set 6 | luebo
# Processing Record 25 of Set 6 | rouissat
# Processing Record 26 of Set 6 | qusmuryn
# Processing Record 27 of Set 6 | egilsstadir
# Processing Record 28 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 29 of Set 6 | fort bragg
# Processing Record 30 of Set 6 | niafunke
# Processing Record 31 of Set 6 | san luis
# Processing Record 32 of Set 6 | noumea
# Processing Record 33 of Set 6 | beichengqu
# Processing Record 34 of Set 6 | ephraim
# Processing Record 35 of Set 6 | klaksvik
# Processing Record 36 of Set 6 | ixtapa
# Processing Record 37 of Set 6 | port glaud
# City not found. Skipping...
# Processing Record 38 of Set 6 | zouerate
# Processing Record 39 of Set 6 | karratha
# Processing Record 40 of Set 6 | kurumul
# City not found. Skipping...
# Processing Record 41 of Set 6 | shizunai-furukawacho
# Processing Record 42 of Set 6 | manokwari
# Processing Record 43 of Set 6 | praia
# Processing Record 44 of Set 6 | panacan
# Processing Record 45 of Set 6 | realeza
# Processing Record 46 of Set 6 | road town
# Processing Record 47 of Set 6 | markaz-e hukumat-e darweshan
# Processing Record 48 of Set 6 | coahuayana de hidalgo
# Processing Record 49 of Set 6 | fale old settlement
# Processing Record 0 of Set 7 | acapulco de juarez
# Processing Record 1 of Set 7 | neftegorsk
# Processing Record 2 of Set 7 | greymouth
# Processing Record 3 of Set 7 | gaiman
# Processing Record 4 of Set 7 | zhigalovo
# Processing Record 5 of Set 7 | 'amran
# City not found. Skipping...
# Processing Record 6 of Set 7 | ghorawal
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | tolanaro
# Processing Record 9 of Set 7 | arnprior
# Processing Record 10 of Set 7 | invercargill
# Processing Record 11 of Set 7 | kruisfontein
# Processing Record 12 of Set 7 | korla
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | vilyuysk
# Processing Record 15 of Set 7 | greenville
# Processing Record 16 of Set 7 | kingaroy
# Processing Record 17 of Set 7 | korschenbroich
# Processing Record 18 of Set 7 | puerto armuelles
# Processing Record 19 of Set 7 | arish
# Processing Record 20 of Set 7 | valle de la pascua
# Processing Record 21 of Set 7 | ust'-barguzin
# Processing Record 22 of Set 7 | kuala terengganu
# Processing Record 23 of Set 7 | pandan
# Processing Record 24 of Set 7 | ocean shores
# Processing Record 25 of Set 7 | olyokminsk
# Processing Record 26 of Set 7 | flying fish cove
# Processing Record 27 of Set 7 | gebre guracha
# Processing Record 28 of Set 7 | tshabong
# Processing Record 29 of Set 7 | tougan
# Processing Record 30 of Set 7 | taft
# Processing Record 31 of Set 7 | san martin
# Processing Record 32 of Set 7 | ketchikan
# Processing Record 33 of Set 7 | mudgee
# Processing Record 34 of Set 7 | balcarce
# Processing Record 35 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 36 of Set 7 | challapata
# Processing Record 37 of Set 7 | munuf
# Processing Record 38 of Set 7 | coquimbo
# Processing Record 39 of Set 7 | nemuro
# Processing Record 40 of Set 7 | taber
# Processing Record 41 of Set 7 | lulea
# Processing Record 42 of Set 7 | manismata
# Processing Record 43 of Set 7 | xindian
# Processing Record 44 of Set 7 | vanino
# Processing Record 45 of Set 7 | cabedelo
# Processing Record 46 of Set 7 | haiku-pauwela
# Processing Record 47 of Set 7 | kerikeri
# Processing Record 48 of Set 7 | viqueque
# Processing Record 49 of Set 7 | kidal
# Processing Record 0 of Set 8 | gubakha
# Processing Record 1 of Set 8 | le port
# Processing Record 2 of Set 8 | vegreville
# Processing Record 3 of Set 8 | robore
# Processing Record 4 of Set 8 | constitucion
# Processing Record 5 of Set 8 | finote selam
# Processing Record 6 of Set 8 | cambria
# Processing Record 7 of Set 8 | moanda
# Processing Record 8 of Set 8 | plattsburgh
# Processing Record 9 of Set 8 | gisborne
# Processing Record 10 of Set 8 | kone
# Processing Record 11 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 12 of Set 8 | sur
# Processing Record 13 of Set 8 | vohipaho
# City not found. Skipping...
# Processing Record 14 of Set 8 | ballina
# Processing Record 15 of Set 8 | xai-xai
# Processing Record 16 of Set 8 | villa gesell
# Processing Record 17 of Set 8 | mil'kovo
# Processing Record 18 of Set 8 | san carlos del zulia
# Processing Record 19 of Set 8 | sisimiut
# Processing Record 20 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 21 of Set 8 | ratnagiri
# Processing Record 22 of Set 8 | tralee
# Processing Record 23 of Set 8 | nadym
# Processing Record 24 of Set 8 | sanctuary point
# Processing Record 25 of Set 8 | tazovsky
# Processing Record 26 of Set 8 | volodymyrets'
# City not found. Skipping...
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | bontang
# Processing Record 29 of Set 8 | taoudenni
# Processing Record 30 of Set 8 | ghat
# Processing Record 31 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 32 of Set 8 | novoishimskiy
# Processing Record 33 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 8 | ankang
# Processing Record 35 of Set 8 | temperance
# Processing Record 36 of Set 8 | saint-philippe
# Processing Record 37 of Set 8 | tura
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | bridgewater
# Processing Record 40 of Set 8 | aguazul
# Processing Record 41 of Set 8 | bac lieu
# Processing Record 42 of Set 8 | prineville
# Processing Record 43 of Set 8 | talcahuano
# Processing Record 44 of Set 8 | chandigarh
# Processing Record 45 of Set 8 | ressano garcia
# Processing Record 46 of Set 8 | nova vicosa
# Processing Record 47 of Set 8 | jaffna
# Processing Record 48 of Set 8 | okahandja
# Processing Record 49 of Set 8 | chambas
# Processing Record 0 of Set 9 | maputo
# Processing Record 1 of Set 9 | dauphin
# Processing Record 2 of Set 9 | malvan
# Processing Record 3 of Set 9 | vorkuta
# Processing Record 4 of Set 9 | presidente medici
# Processing Record 5 of Set 9 | kilindoni
# Processing Record 6 of Set 9 | sept-iles
# Processing Record 7 of Set 9 | lethem
# Processing Record 8 of Set 9 | novyye burasy
# Processing Record 9 of Set 9 | aur
# Processing Record 10 of Set 9 | la passe
# Processing Record 11 of Set 9 | edd
# Processing Record 12 of Set 9 | ha'il
# Processing Record 13 of Set 9 | aldan
# Processing Record 14 of Set 9 | udachny
# Processing Record 15 of Set 9 | selfoss
# Processing Record 16 of Set 9 | vangaindrano
# Processing Record 17 of Set 9 | grande prairie
# Processing Record 18 of Set 9 | queenstown
# Processing Record 19 of Set 9 | manakara
# Processing Record 20 of Set 9 | tangalle
# Processing Record 21 of Set 9 | enterprise
# Processing Record 22 of Set 9 | ad dilam
# Processing Record 23 of Set 9 | pursat
# Processing Record 24 of Set 9 | bikenibeu village
# Processing Record 25 of Set 9 | paracuru
# Processing Record 26 of Set 9 | mhamid
# Processing Record 27 of Set 9 | el granada
# Processing Record 28 of Set 9 | santa vitoria do palmar
# Processing Record 29 of Set 9 | dinguiraye
# Processing Record 30 of Set 9 | panjab
# Processing Record 31 of Set 9 | saynshand
# Processing Record 32 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 33 of Set 9 | jayapura
# Processing Record 34 of Set 9 | burnie
# Processing Record 35 of Set 9 | miyaly
# Processing Record 36 of Set 9 | tsiombe
# Processing Record 37 of Set 9 | nieuw amsterdam
# Processing Record 38 of Set 9 | zhezqazghan
# Processing Record 39 of Set 9 | alloa
# Processing Record 40 of Set 9 | new norfolk
# Processing Record 41 of Set 9 | alofi
# Processing Record 42 of Set 9 | san fernando de apure
# Processing Record 43 of Set 9 | clarksville
# Processing Record 44 of Set 9 | yagry
# City not found. Skipping...
# Processing Record 45 of Set 9 | lompoc
# Processing Record 46 of Set 9 | alapayevsk
# Processing Record 47 of Set 9 | gallivare
# City not found. Skipping...
# Processing Record 48 of Set 9 | weldon spring
# Processing Record 49 of Set 9 | beira
# Processing Record 0 of Set 10 | mogocha
# Processing Record 1 of Set 10 | ust-nera
# Processing Record 2 of Set 10 | kailua-kona
# Processing Record 3 of Set 10 | bardai
# Processing Record 4 of Set 10 | atar
# Processing Record 5 of Set 10 | sorong
# Processing Record 6 of Set 10 | arkadelphia
# Processing Record 7 of Set 10 | broome
# Processing Record 8 of Set 10 | luanda
# Processing Record 9 of Set 10 | ponta delgada
# Processing Record 10 of Set 10 | fort st. john
# Processing Record 11 of Set 10 | mezhova
# Processing Record 12 of Set 10 | margate
# Processing Record 13 of Set 10 | morant bay
# Processing Record 14 of Set 10 | fada
# Processing Record 15 of Set 10 | portland
# Processing Record 16 of Set 10 | funafuti
# Processing Record 17 of Set 10 | berdigestyakh
# Processing Record 18 of Set 10 | pacific grove
# Processing Record 19 of Set 10 | christchurch
# Processing Record 20 of Set 10 | vila franca do campo
# Processing Record 21 of Set 10 | sandnessjoen
# Processing Record 22 of Set 10 | muana
# Processing Record 23 of Set 10 | bellegarde-sur-valserine
# Processing Record 24 of Set 10 | happy valley-goose bay
# Processing Record 25 of Set 10 | tarauaca
# Processing Record 26 of Set 10 | tofol
# Processing Record 27 of Set 10 | tank
# Processing Record 28 of Set 10 | rajura
# Processing Record 29 of Set 10 | conceicao da barra
# Processing Record 30 of Set 10 | malango
# Processing Record 31 of Set 10 | vadso
# Processing Record 32 of Set 10 | wellston
# Processing Record 33 of Set 10 | coxim
# Processing Record 34 of Set 10 | oriximina
# Processing Record 35 of Set 10 | koniecpol
# Processing Record 36 of Set 10 | nadi
# Processing Record 37 of Set 10 | aksu
# Processing Record 38 of Set 10 | bentiu
# Processing Record 39 of Set 10 | lata
# Processing Record 40 of Set 10 | caburan
# Processing Record 41 of Set 10 | tenenkou
# Processing Record 42 of Set 10 | evinayong
# Processing Record 43 of Set 10 | wurtulla
# Processing Record 44 of Set 10 | sale
# Processing Record 45 of Set 10 | mount pearl
# Processing Record 46 of Set 10 | progreso
# Processing Record 47 of Set 10 | cristalina
# Processing Record 48 of Set 10 | nagqu
# Processing Record 49 of Set 10 | ewo
# Processing Record 0 of Set 11 | enniskillen
# Processing Record 1 of Set 11 | manali
# Processing Record 2 of Set 11 | santa ana
# Processing Record 3 of Set 11 | miches
# Processing Record 4 of Set 11 | tocopilla
# Processing Record 5 of Set 11 | vernon
# Processing Record 6 of Set 11 | itanhem
# Processing Record 7 of Set 11 | gadzhiyevo
# Processing Record 8 of Set 11 | princeville
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | maralal
# Processing Record 11 of Set 11 | ceeldheer
# Processing Record 12 of Set 11 | santa marta
# Processing Record 13 of Set 11 | balqash
# Processing Record 14 of Set 11 | mossel bay
# Processing Record 15 of Set 11 | ishigaki
# Processing Record 16 of Set 11 | port hedland
# Processing Record 17 of Set 11 | hanceville
# Processing Record 18 of Set 11 | mili
# Processing Record 19 of Set 11 | susuman
# Processing Record 20 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 21 of Set 11 | floro
# Processing Record 22 of Set 11 | saint-pierre
# Processing Record 23 of Set 11 | sao tome
# Processing Record 24 of Set 11 | guarapari
# Processing Record 25 of Set 11 | callao
# Processing Record 26 of Set 11 | znamenskoye
# Processing Record 27 of Set 11 | whakatane
# Processing Record 28 of Set 11 | basco
# Processing Record 29 of Set 11 | saldanha
# Processing Record 30 of Set 11 | yamada
# Processing Record 31 of Set 11 | licheng
# Processing Record 32 of Set 11 | praia da vitoria
# Processing Record 33 of Set 11 | seydisehir
# Processing Record 34 of Set 11 | birstein
# Processing Record 35 of Set 11 | les avirons
# Processing Record 36 of Set 11 | agapovka
# Processing Record 37 of Set 11 | jamul
# Processing Record 38 of Set 11 | nyurba
# Processing Record 39 of Set 11 | port moresby
# Processing Record 40 of Set 11 | sinop
# Processing Record 41 of Set 11 | kamiiso
# Processing Record 42 of Set 11 | poronaysk
# Processing Record 43 of Set 11 | guiuan
# Processing Record 44 of Set 11 | baranchinskiy
# Processing Record 45 of Set 11 | port douglas
# Processing Record 46 of Set 11 | bulawayo
# Processing Record 47 of Set 11 | champerico
# Processing Record 48 of Set 11 | coronado
# Processing Record 49 of Set 11 | alaghsas
# Processing Record 0 of Set 12 | codrington
# Processing Record 1 of Set 12 | zaozersk
# Processing Record 2 of Set 12 | dolores
# Processing Record 3 of Set 12 | del rio
# Processing Record 4 of Set 12 | pestovo
# Processing Record 5 of Set 12 | mong cai
# City not found. Skipping...
# Processing Record 6 of Set 12 | tvoroyri
# Processing Record 7 of Set 12 | prince rupert
# Processing Record 8 of Set 12 | zyryanovsk
# Processing Record 9 of Set 12 | cable beach
# City not found. Skipping...
# Processing Record 10 of Set 12 | hit
# Processing Record 11 of Set 12 | teknaf
# Processing Record 12 of Set 12 | el calafate
# Processing Record 13 of Set 12 | zholymbet
# Processing Record 14 of Set 12 | aykhal
# Processing Record 15 of Set 12 | okhotsk
# Processing Record 16 of Set 12 | cam pha mines
# Processing Record 17 of Set 12 | riyadh
# Processing Record 18 of Set 12 | priargunsk
# Processing Record 19 of Set 12 | azangaro
# Processing Record 20 of Set 12 | west bay
# Processing Record 21 of Set 12 | port augusta
# Processing Record 22 of Set 12 | lewisburg
# Processing Record 23 of Set 12 | st. paul
# Processing Record 24 of Set 12 | tasek glugor
# Processing Record 25 of Set 12 | kozhevnikovo
# Processing Record 26 of Set 12 | sao vicente
# Processing Record 27 of Set 12 | tyukalinsk
# Processing Record 28 of Set 12 | bandar-e anzali
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   ilulissat  69.2167  -51.1000      7.01        76           0        2.06
# 1      bethel  41.3712  -73.4140     24.72        81           0        4.12
# 2  st. john's  47.5649  -52.7093     19.04        82         100        8.75
# 3   adamstown -25.0660 -130.1015     19.50        60          28        3.87
# 4   boguchany  58.3814   97.4531     26.91        45          57        2.75
#
#   Country        Date
# 0      GL  1690432388
# 1      US  1690432388
# 2      CA  1690432208
# 3      PN  1690432388
# 4      RU  1690432389

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   ilulissat  69.2167  -51.1000      7.01        76           0        2.06
# 1      bethel  41.3712  -73.4140     24.72        81           0        4.12
# 2  st. john's  47.5649  -52.7093     19.04        82         100        8.75
# 3   adamstown -25.0660 -130.1015     19.50        60          28        3.87
# 4   boguchany  58.3814   97.4531     26.91        45          57        2.75
#
#   Country        Date
# 0      GL  1690432388
# 1      US  1690432388
# 2      CA  1690432208
# 3      PN  1690432388
# 4      RU  1690432389

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         ilulissat  69.2167  -51.1000      7.01        76           0
# 1            bethel  41.3712  -73.4140     24.72        81           0
# 2        st. john's  47.5649  -52.7093     19.04        82         100
# 3         adamstown -25.0660 -130.1015     19.50        60          28
# 4         boguchany  58.3814   97.4531     26.91        45          57
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      GL  1690432388
# 1              4.12      US  1690432388
# 2              8.75      CA  1690432208
# 3              3.87      PN  1690432388
# 4              2.75      RU  1690432389

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor= "black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("Latitude Vs. Temperature")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor= "black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("Latitude Vs. Humidity")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor= "black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("Latitude Vs. Cloudiness")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor= "black",
    linewidths=1,
    marker="o",
    alpha=0.8,
    label="Cities"
)

# Incorporate the other graph properties
plt.title("Latitude Vs. Wind Speed")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_plot_regression(x,y, coordinates,xtitle, ytitle):
    (slope, intercept,rvalue, pvalue,ste) = linregress(x,y)
    regressionline = slope * x + intercept
    equation = f"y={round(slope,2)} * x + {round(intercept,2)}"
    
    plt.scatter(x, y, color='blue', label='Data')
    plt.plot(x, regressionline, color='red')
    plt.xlabel(xtitle)
    plt.ylabel(ytitle)
    plt.title('Linear Regression Plot')
    plt.legend()
    plt.annotate(equation, coordinates, fontsize=10, color='blue')
    plt.grid(True)
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         ilulissat  69.2167 -51.1000      7.01        76           0
# 1            bethel  41.3712 -73.4140     24.72        81           0
# 2        st. john's  47.5649 -52.7093     19.04        82         100
# 4         boguchany  58.3814  97.4531     26.91        45          57
# 5         iskateley  67.6803  53.1512     20.74        58          90
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      GL  1690432388
# 1              4.12      US  1690432388
# 2              8.75      CA  1690432208
# 4              2.75      RU  1690432389
# 5              2.44      RU  1690432389

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                adamstown -25.0660 -130.1015     19.50        60          28
# 6        port-aux-francais -49.3500   70.2167      4.61        79          83
# 16            puerto ayora  -0.7393  -90.3518     24.75        93          86
# 18               grytviken -54.2811  -36.5092      0.98        99         100
# 19          puerto natales -51.7236  -72.4875     -2.18        94         100
#
#          Wind Speed Country        Date
# City_ID
# 3              3.87      PN  1690432388
# 6             15.30      TF  1690432249
# 16             2.24      EC  1690432358
# 18             5.68      GS  1690432392
# 19             1.22      CL  1690432361

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
coordinates=(0,5)
lat = northern_hemi_df['Lat']
maxtemp = northern_hemi_df['Max Temp']
xtitle = "Latitude"
ytitle = "Max Temperature"
linear_plot_regression(lat,maxtemp, coordinates,xtitle,ytitle)

# %%
# Linear regression on Southern Hemisphere
coordinates=(-20,-5)
lat = southern_hemi_df['Lat']
maxtemp = southern_hemi_df['Max Temp']
xtitle = "Latitude"
ytitle = "Max Temperature"
linear_plot_regression(lat,maxtemp, coordinates,xtitle,ytitle)

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, we see that there is a negative correlation between latitude and temperature versus the southern hemisphere has a positive correlation between latitude and temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
coordinates=(0,5)
lat = northern_hemi_df['Lat']
humidity = northern_hemi_df['Humidity']
xtitle = "Latitude"
ytitle = "Humidity"
linear_plot_regression(lat,humidity, coordinates,xtitle,ytitle)

# %%
# Southern Hemisphere
coordinates=(-55,40)
lat = southern_hemi_df['Lat']
humidity = southern_hemi_df['Humidity']
xtitle = "Latitude"
ytitle = "Humidity"
linear_plot_regression(lat,humidity, coordinates,xtitle,ytitle)

# %% [markdown]
# **Discussion about the linear relationship:** In both hemispheres, we see that the regression is fairly flat meaning there isn't much change, which is indicated by the slope. The intercepts are also very close to each other.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
coordinates=(0,10)
lat = northern_hemi_df['Lat']
cloudiness = northern_hemi_df['Cloudiness']
xtitle = "Latitude"
ytitle = "Cloudiness"
linear_plot_regression(lat,cloudiness, coordinates,xtitle,ytitle)

# %%
# Southern Hemisphere
coordinates=(-50,10)
lat = southern_hemi_df['Lat']
cloudiness = southern_hemi_df['Cloudiness']
xtitle = "Latitude"
ytitle = "Cloudiness"
linear_plot_regression(lat,cloudiness, coordinates,xtitle,ytitle)

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres have a wide variety of data points and don't really show a regression line that implies a signifcant statistic.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
coordinates=(0,12.5)
lat = northern_hemi_df['Lat']
windspeed = northern_hemi_df['Wind Speed']
xtitle = "Latitude"
ytitle = "Wind Speed"
linear_plot_regression(lat,windspeed, coordinates,xtitle,ytitle)

# %%
# Southern Hemisphere
coordinates=(-50,12)
lat = southern_hemi_df['Lat']
windspeed = southern_hemi_df['Wind Speed']
xtitle = "Latitude"
ytitle = "Wind Speed"
linear_plot_regression(lat,windspeed, coordinates,xtitle,ytitle)

# %% [markdown]
# **Discussion about the linear relationship:** The slope for both hemispheres are the same. However, the y intercept for the northern hemisphere, implies that wind speed is greater.
