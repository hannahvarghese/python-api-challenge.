# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   ilulissat  69.2167  -51.1000      7.01        76           0
# 1        1      bethel  41.3712  -73.4140     24.72        81           0
# 2        2  st. john's  47.5649  -52.7093     19.04        82         100
# 3        3   adamstown -25.0660 -130.1015     19.50        60          28
# 4        4   boguchany  58.3814   97.4531     26.91        45          57
#
#    Wind Speed Country        Date
# 0        2.06      GL  1690432388
# 1        4.12      US  1690432388
# 2        8.75      CA  1690432208
# 3        3.87      PN  1690432388
# 4        2.75      RU  1690432389

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points('Lng', 
                                      'Lat',
                                      geo = True,
                                      size = 'Humidity',
                                      scale = 1,
                                      color = 'City',
                                      alpha = 0.5,
                                      tiles = 'OSM',
                                      frame_width = 700,
                                      frame_height = 500)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
mintemp = 21
maxtemp = 27
windspeed = 4.5
cloudiness = 0

idealweathercondition = city_data_df[
    (city_data_df['Max Temp'] > mintemp) &
    (city_data_df['Max Temp'] < maxtemp) &
    (city_data_df['Wind Speed'] < windspeed) &
    (city_data_df['Cloudiness'] == cloudiness)
]

# Drop any rows with null values
city_data_df=city_data_df.dropna()

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   ilulissat  69.2167  -51.1000      7.01        76           0
# 1        1      bethel  41.3712  -73.4140     24.72        81           0
# 2        2  st. john's  47.5649  -52.7093     19.04        82         100
# 3        3   adamstown -25.0660 -130.1015     19.50        60          28
# 4        4   boguchany  58.3814   97.4531     26.91        45          57
#
#    Wind Speed Country        Date
# 0        2.06      GL  1690432388
# 1        4.12      US  1690432388
# 2        8.75      CA  1690432208
# 3        3.87      PN  1690432388
# 4        2.75      RU  1690432389

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
columns= ['City', 'Country', 'Lat','Lng', 'Humidity']

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df=city_data_df[columns].copy()

# Display sample data
hotel_df.head()
# Out:
#          City Country      Lat       Lng  Humidity
# 0   ilulissat      GL  69.2167  -51.1000        76
# 1      bethel      US  41.3712  -73.4140        81
# 2  st. john's      CA  47.5649  -52.7093        82
# 3   adamstown      PN -25.0660 -130.1015        60
# 4   boguchany      RU  58.3814   97.4531        45

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# bethel - nearest hotel: Hampton Inn Danbury
# st. john's - nearest hotel: Alt Hotel
# adamstown - nearest hotel: No hotel found
# boguchany - nearest hotel: Полет
# iskateley - nearest hotel: Авантаж
# port-aux-francais - nearest hotel: Keravel
# i-n-salah - nearest hotel: باجودة
# olonkinbyen - nearest hotel: No hotel found
# winslow - nearest hotel: La Posada Hotel
# val-d'or - nearest hotel: Quality Inn & Suites
# badger - nearest hotel: Hotel North Pole
# hamilton - nearest hotel: North Vista Manor
# okha - nearest hotel: Сфера
# qaqortoq - nearest hotel: Hotel Qaqortoq
# namtsy - nearest hotel: No hotel found
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# arteche - nearest hotel: No hotel found
# grytviken - nearest hotel: No hotel found
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# iqaluit - nearest hotel: Frobisher Inn
# west island - nearest hotel: Cocos Village Bungalows
# hithadhoo - nearest hotel: Pebbles Inn
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# san antonio de pale - nearest hotel: No hotel found
# paide - nearest hotel: Paide SPA hotell
# vila velha - nearest hotel: Hotel Prainha
# waitangi - nearest hotel: Hotel Chathams
# wailea - nearest hotel: Hakalau Vacation Rental
# izyum - nearest hotel: Терем
# kingston - nearest hotel: Aphrodite Hotel
# albany - nearest hotel: No hotel found
# zapopan - nearest hotel: Wyndham Garden Guadalajara Acueducto
# wajir - nearest hotel: Kilimanjaro
# howard springs - nearest hotel: No hotel found
# anadyr - nearest hotel: Гостевой дом
# punta arenas - nearest hotel: Hotel Lacolet
# luganville - nearest hotel: Beachfront Resort
# kaya - nearest hotel: Hôtel Kaziendé
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# weiser - nearest hotel: No hotel found
# utrik - nearest hotel: No hotel found
# yuzhno-kurilsk - nearest hotel: Dom Druzhby
# tarko-sale - nearest hotel: Вынгапур
# kapuskasing - nearest hotel: Travelodge
# kandyagash - nearest hotel: No hotel found
# bamboo flat - nearest hotel: Hotel Megapode Nest
# viedma - nearest hotel: Níjar
# port elizabeth - nearest hotel: Waterford Hotel
# grand falls-windsor - nearest hotel: Hotel Robin Hood
# nicoya - nearest hotel: Hotel marianela
# alice springs - nearest hotel: Aurora Alice Springs
# dwarka - nearest hotel: The Dwarika Hotel
# atafu village - nearest hotel: No hotel found
# new plymouth - nearest hotel: Carrington Motel
# bomadi - nearest hotel: No hotel found
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# guerrero negro - nearest hotel: Plaza sal paraiso
# georgetown - nearest hotel: Page 63 hostel
# akureyri - nearest hotel: Hótel Norðurland
# lihue - nearest hotel: Kauai Palms
# natal - nearest hotel: Natal Palace Hotel
# katsuura - nearest hotel: 潮騒の宿
# port mathurin - nearest hotel: Escale Vacances
# major isidoro - nearest hotel: Pousada Brilho da Lua
# port alfred - nearest hotel: No hotel found
# san-pedro - nearest hotel: Hôtel La Cité De San Pédro
# zhangatas - nearest hotel: Арман
# bonthe - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# altay - nearest hotel: Sunshine Holiday Hotel
# thunder bay - nearest hotel: Hampton Inn & Suites by Hilton Thunder Bay
# laguna - nearest hotel: Holiday Inn Express & Suites
# dudinka - nearest hotel: Виктория
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# la'ie - nearest hotel: No hotel found
# puerto ayacucho - nearest hotel: Hotel VENETUR Amazonas
# jamestown - nearest hotel: DoubleTree Jamestown
# tiksi - nearest hotel: Арктика
# hawaiian paradise park - nearest hotel: No hotel found
# caleta de carquin - nearest hotel: Hotel Mi Choacan
# la ronge - nearest hotel: La Ronge Hotel and Suites
# lebu - nearest hotel: No hotel found
# belyy yar - nearest hotel: No hotel found
# peniche - nearest hotel: Residencial Maciel
# whitehorse - nearest hotel: Town & Mountain Hotel
# edinburgh of the seven seas - nearest hotel: No hotel found
# talnakh - nearest hotel: Талнах
# pacasmayo - nearest hotel: Playa Linda
# bilibino - nearest hotel: No hotel found
# brisas de zicatela - nearest hotel: Casa de Olas
# den burg - nearest hotel: De Lindeboom
# island harbour - nearest hotel: Premier Inn
# tanjung pandan - nearest hotel: Billiton Hotel & Club
# abepura - nearest hotel: Yoyo
# touros - nearest hotel: Pousada Atlântico
# papatowai - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# carahue - nearest hotel: No hotel found
# stanley - nearest hotel: Hotel 52
# constantia - nearest hotel: Hotel Chérica
# arawa - nearest hotel: No hotel found
# polyarnyy - nearest hotel: No hotel found
# zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# bay roberts - nearest hotel: No hotel found
# nova sintra - nearest hotel: Residência Ka Dencho
# keflavik - nearest hotel: Núpan Deluxe
# uturoa - nearest hotel: Hawaiki Nui hotel
# krutinka - nearest hotel: No hotel found
# toba - nearest hotel: 鳥羽シーサイドホテル
# argo - nearest hotel: Apollon Hotel
# palangkaraya - nearest hotel: Swiss-Belhotel
# tokar - nearest hotel: No hotel found
# mejit - nearest hotel: No hotel found
# isafjordur - nearest hotel: Hótel Horn
# aasiaat - nearest hotel: SØMA
# naliya - nearest hotel: No hotel found
# daugavpils - nearest hotel: SanMari
# ancud - nearest hotel: Cabañas
# bengkulu - nearest hotel: Dena Hotel
# celestun - nearest hotel: Hotel Flamingo Playa
# longyearbyen - nearest hotel: The Vault
# ribeira grande - nearest hotel: Hospedaria JSF
# namie - nearest hotel: HOTELなみえ
# margaret river - nearest hotel: Margaret River Hotel
# remire-montjoly - nearest hotel: Complexe Belova
# ambovombe - nearest hotel: La source
# sinabang - nearest hotel: No hotel found
# hasaki - nearest hotel: 大新旅館
# garissa - nearest hotel: Hiddig Hotel
# blackmans bay - nearest hotel: Villa Howden
# tazacorte - nearest hotel: App Leyma
# borzya - nearest hotel: гостиница Глория
# lukolela - nearest hotel: No hotel found
# enewetak - nearest hotel: No hotel found
# avarua - nearest hotel: Paradise Inn
# okondja - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# warman - nearest hotel: Warman Hotel
# pulgaon - nearest hotel: No hotel found
# avanigadda - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# rikaze - nearest hotel: Gesar Hotel
# reggane - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# suva - nearest hotel: Extension 68
# geraldton - nearest hotel: Ocean Centre Hotel
# masterton - nearest hotel: Copthorne Hotel Solway Park
# yanykurgan - nearest hotel: No hotel found
# el sauzal de rodriguez - nearest hotel: Hotel Sausalito
# wick - nearest hotel: Mackays Hotel
# nogliki - nearest hotel: Ноглики
# palmer - nearest hotel: No hotel found
# aksaray - nearest hotel: Grand Saatcioglu Otel
# pariaman - nearest hotel: HOTEL NAN TONGGA
# el dorado - nearest hotel: No hotel found
# vorgashor - nearest hotel: София
# palikir - national government center - nearest hotel: Mangrove Bay Hotel
# colonia - nearest hotel: Wasserturm Hotel Cologne
# minas de marcona - nearest hotel: No hotel found
# thompson - nearest hotel: Thompson Inn
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# pisco - nearest hotel: La Portada
# hermanus - nearest hotel: Aloe guest house
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# porbandar - nearest hotel: Toran Tourist Bungalow
# kindu - nearest hotel: No hotel found
# new amsterdam - nearest hotel: Church View Hotel
# taltal - nearest hotel: Hostería Taltal
# bani walid - nearest hotel: فندق الزيتونة
# yellowknife - nearest hotel: No hotel found
# ndofane - nearest hotel: No hotel found
# hilo - nearest hotel: Dolphin Bay Hotel
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# sunrise manor - nearest hotel: Holiday Inn Express Las Vegas - Nellis
# tambacounda - nearest hotel: Le relais de Tamba
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# antofagasta - nearest hotel: Hotel Colón
# kavalerovo - nearest hotel: Гостиница
# mpumalanga - nearest hotel: No hotel found
# kununurra - nearest hotel: Kununurra Country Club Resort
# mount isa - nearest hotel: Ibis Styles
# namibe - nearest hotel: Hotel Chik Chik Namibe
# broken hill - nearest hotel: Ibis Styles
# miquelon - nearest hotel: No hotel found
# prince albert - nearest hotel: No hotel found
# kodiak - nearest hotel: Shelikof Lodge
# nuuk - nearest hotel: Nordbo
# ulladulla - nearest hotel: Hotel Marlin
# meulaboh - nearest hotel: Hotel Meuligou
# tinghir - nearest hotel: Riad Agraw
# birjand - nearest hotel: مهمانسرای جهانگردی بیرجند
# ciudad general teran - nearest hotel: No hotel found
# ola - nearest hotel: No hotel found
# piti village - nearest hotel: The Cliff Hotel
# yuksekova - nearest hotel: Avazem
# chonchi - nearest hotel: Hotel Huildín
# daru - nearest hotel: Kuki
# santo antonio - nearest hotel: Pousada Onça Puma
# port shepstone - nearest hotel: The Spot Backpackers'
# serik - nearest hotel: Sapphire Homes
# besikduzu - nearest hotel: Öğretmenevi
# newman - nearest hotel: No hotel found
# cartagena del chaira - nearest hotel: Los Corceles
# qamdo - nearest hotel: 银杏商务宾馆
# afaahiti - nearest hotel: Omati Lodge
# jinchang - nearest hotel: No hotel found
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# cabo san lucas - nearest hotel: Comfort Rooms
# marka - nearest hotel: Salsabiil Hotel
# al jawf - nearest hotel: No hotel found
# nouadhibou - nearest hotel: Hotel valencia
# sitka - nearest hotel: Aspen Suites Hotel
# fonte boa - nearest hotel: No hotel found
# kupang - nearest hotel: HOTEL SALUNGA
# pemba - nearest hotel: Hotel Rafael
# axim - nearest hotel: Axim Beach Hotel
# klyuchi - nearest hotel: No hotel found
# sarmiento - nearest hotel: Ismar
# kindia - nearest hotel: Hôtel buffet de la gare de Kindia
# palapye - nearest hotel: Palapaye Hotel
# kayyerkan - nearest hotel: No hotel found
# goundam - nearest hotel: No hotel found
# weno - nearest hotel: High Tide Hotel
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# marco island - nearest hotel: JW Marriott Marco Island Beach Resort
# amga - nearest hotel: "АммА"
# dalcahue - nearest hotel: Hospedaje
# wangkui - nearest hotel: No hotel found
# howrah - nearest hotel: Sun India Guest House
# richards bay - nearest hotel: Bon Hotel Waterfront
# acajutla - nearest hotel: Hotel Lara
# fangshan - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# vallenar - nearest hotel: Hotel del Marqués
# gumla - nearest hotel: No hotel found
# vrangel' - nearest hotel: No hotel found
# ishinomaki - nearest hotel: 丹美旅館
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# rongelap - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# jackson - nearest hotel: Brookside
# benghazi - nearest hotel: ترجاب
# arno - nearest hotel: Pensionat Grisslehamns
# wuwei - nearest hotel: Hepingli Boutique Hotel
# arraial do cabo - nearest hotel: No hotel found
# mkushi - nearest hotel: Shalom Lodge
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# isola di capo rizzuto - nearest hotel: No hotel found
# mudanya - nearest hotel: Montania Special Class Hotel
# ranau - nearest hotel: Logde 37T
# rio verde de mato grosso - nearest hotel: No hotel found
# oliena - nearest hotel: Cooperativa Turistica ENIS
# lerwick - nearest hotel: Grand Hotel
# kibaha - nearest hotel: ART hotel
# kuala belait - nearest hotel: Hotel Sentosa
# xining - nearest hotel: Qinghai hotel
# torghay - nearest hotel: No hotel found
# nizhneangarsk - nearest hotel: No hotel found
# luebo - nearest hotel: No hotel found
# rouissat - nearest hotel: فندق الأروي الذهبي
# qusmuryn - nearest hotel: No hotel found
# egilsstadir - nearest hotel: Valaskjálf
# fort bragg - nearest hotel: Airborne Inn Lodging
# niafunke - nearest hotel: No hotel found
# san luis - nearest hotel: Hotel Dos Venados
# noumea - nearest hotel: Hotel Gondwana
# beichengqu - nearest hotel: 春江大酒店
# ephraim - nearest hotel: Willow Creek Inn
# klaksvik - nearest hotel: Hotel Klaksvik
# ixtapa - nearest hotel: Ma. Cristina
# zouerate - nearest hotel: فندق تيرس زمور
# karratha - nearest hotel: Karratha International Hotel
# shizunai-furukawacho - nearest hotel: No hotel found
# manokwari - nearest hotel: Hotel Arfak
# praia - nearest hotel: Casa Sodadi
# panacan - nearest hotel: Gorayan Lodge
# realeza - nearest hotel: No hotel found
# road town - nearest hotel: No hotel found
# markaz-e hukumat-e darweshan - nearest hotel: No hotel found
# coahuayana de hidalgo - nearest hotel: No hotel found
# fale old settlement - nearest hotel: No hotel found
# acapulco de juarez - nearest hotel: Hotel del Valle
# neftegorsk - nearest hotel: Надежда
# greymouth - nearest hotel: Recreation Hotel
# gaiman - nearest hotel: yr hen ffordd
# zhigalovo - nearest hotel: Лена-ТУР
# ghorawal - nearest hotel: No hotel found
# tolanaro - nearest hotel: Hôtel Mahavokey
# arnprior - nearest hotel: Quality Inn
# invercargill - nearest hotel: The Grand
# kruisfontein - nearest hotel: No hotel found
# korla - nearest hotel: Silver Star Hotel
# isangel - nearest hotel: Tanna Lodge
# vilyuysk - nearest hotel: Мария
# greenville - nearest hotel: Quality Inn
# kingaroy - nearest hotel: No hotel found
# korschenbroich - nearest hotel: Hotel Zur Alten Post
# puerto armuelles - nearest hotel: Coco del Mar
# arish - nearest hotel: سينا
# valle de la pascua - nearest hotel: Palace Hotel
# ust'-barguzin - nearest hotel: Байкальский бриз
# kuala terengganu - nearest hotel: Uncle Homestay
# pandan - nearest hotel: No hotel found
# ocean shores - nearest hotel: Collins Inn & Seaside Cottages
# olyokminsk - nearest hotel: Колос
# flying fish cove - nearest hotel: Christmas Island Lodge
# gebre guracha - nearest hotel: Selale
# tshabong - nearest hotel: No hotel found
# tougan - nearest hotel: Hotel ZEELA
# taft - nearest hotel: هتل شیرکوه تفت
# san martin - nearest hotel: Hotel Lacava
# ketchikan - nearest hotel: Cape Fox Lodge
# mudgee - nearest hotel: Oriental Hotel
# balcarce - nearest hotel: Superior 646 Hotel Balcarce
# challapata - nearest hotel: Residencial Marian
# munuf - nearest hotel: No hotel found
# coquimbo - nearest hotel: Hotel Iberia
# nemuro - nearest hotel: イーストハーバーホテル
# taber - nearest hotel: No hotel found
# lulea - nearest hotel: Clarion Hotel Sense
# manismata - nearest hotel: No hotel found
# xindian - nearest hotel: 亚洲酒店
# vanino - nearest hotel: Пять Звёзд
# cabedelo - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# kerikeri - nearest hotel: Avalon Resort
# viqueque - nearest hotel: Hotel Wailakurini
# kidal - nearest hotel: No hotel found
# gubakha - nearest hotel: Алмаз
# le port - nearest hotel: No hotel found
# vegreville - nearest hotel: Hotello
# robore - nearest hotel: Lajas
# constitucion - nearest hotel: Hostal Alameda
# finote selam - nearest hotel: No hotel found
# cambria - nearest hotel: Olallieberry Inn
# moanda - nearest hotel: Matsissa
# plattsburgh - nearest hotel: Golden Gate Hotel
# gisborne - nearest hotel: Portside Hotel
# kone - nearest hotel: Pacifik Appartels
# sur - nearest hotel: Sur Hotel
# ballina - nearest hotel: Ballina Beach Resort
# xai-xai - nearest hotel: No hotel found
# villa gesell - nearest hotel: Hotel El Faro
# mil'kovo - nearest hotel: Дрозды
# san carlos del zulia - nearest hotel: Hotel Bolívar
# sisimiut - nearest hotel: Sømandshjemmet
# ratnagiri - nearest hotel: Vihar
# tralee - nearest hotel: The Ashe Hotel
# nadym - nearest hotel: Янтарная
# sanctuary point - nearest hotel: Dungowan Accommodation
# tazovsky - nearest hotel: Тазовчанка
# cidreira - nearest hotel: Hotel Castelo
# bontang - nearest hotel: Hotel Sederhana
# taoudenni - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
# novoishimskiy - nearest hotel: No hotel found
# ankang - nearest hotel: 金友商务酒店
# temperance - nearest hotel: Courtyard by Marriott Toledo North
# saint-philippe - nearest hotel: Le Baril
# tura - nearest hotel: No hotel found
# kavaratti - nearest hotel: No hotel found
# bridgewater - nearest hotel: Comfort Inn
# aguazul - nearest hotel: Hotel Herblan
# bac lieu - nearest hotel: Khách sạn Bạc Liêu
# prineville - nearest hotel: Best Western
# talcahuano - nearest hotel: Club Recreativo Armada de Chile
# chandigarh - nearest hotel: City Plaza 17
# ressano garcia - nearest hotel: River Hill Lodge
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# jaffna - nearest hotel: Three Star Hotel
# chambas - nearest hotel: Hotel Colón
# maputo - nearest hotel: Mozaika
# dauphin - nearest hotel: No hotel found
# malvan - nearest hotel: Hotel Silver Sand
# vorkuta - nearest hotel: "Мегаполис"
# presidente medici - nearest hotel: No hotel found
# kilindoni - nearest hotel: Ibizza Inn
# sept-iles - nearest hotel: Château Arnaud
# lethem - nearest hotel: Hotel Amazonas
# novyye burasy - nearest hotel: Общежитие
# aur - nearest hotel: No hotel found
# la passe - nearest hotel: L'Estuaire
# edd - nearest hotel: No hotel found
# ha'il - nearest hotel: فندق كلاسيك
# aldan - nearest hotel: гостинница Велком Плаза
# udachny - nearest hotel: Вилюй
# selfoss - nearest hotel: Miðgarður
# vangaindrano - nearest hotel: Fanilo
# grande prairie - nearest hotel: Sandman Hotel Grande Prairie
# queenstown - nearest hotel: Queens Hotel
# manakara - nearest hotel: Hotel H1
# tangalle - nearest hotel: Coco Tangalla
# enterprise - nearest hotel: Highland Inn
# ad dilam - nearest hotel: No hotel found
# pursat - nearest hotel: No hotel found
# bikenibeu village - nearest hotel: Otintaai Hotel
# paracuru - nearest hotel: Vento Brasil
# mhamid - nearest hotel: Hotel Kasbah Azalay
# el granada - nearest hotel: Beach House
# santa vitoria do palmar - nearest hotel: Hotel Brasil
# dinguiraye - nearest hotel: No hotel found
# panjab - nearest hotel: Bazar Dan Siah Darah - بازار دان سیاه دره
# saynshand - nearest hotel: No hotel found
# jayapura - nearest hotel: Hotel Jasmine Jayapura
# burnie - nearest hotel: Burnie Central TownHouse Hotel
# miyaly - nearest hotel: Ахан
# tsiombe - nearest hotel: No hotel found
# nieuw amsterdam - nearest hotel: Leonsberg Lodge
# zhezqazghan - nearest hotel: No hotel found
# alloa - nearest hotel: Dunmar House Hotel
# new norfolk - nearest hotel: Woodbridge on the Derwent
# alofi - nearest hotel: Matavai Resort
# san fernando de apure - nearest hotel: Hotel Plaza
# clarksville - nearest hotel: Riverview Inn
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# alapayevsk - nearest hotel: Металлург
# weldon spring - nearest hotel: Residence Inn by Marriott St. Louis O'Fallon
# beira - nearest hotel: Hotel Savoy
# mogocha - nearest hotel: 7Ka
# ust-nera - nearest hotel: гостиница "Солнечная"
# kailua-kona - nearest hotel: Kona Seaside Hotel
# bardai - nearest hotel: No hotel found
# atar - nearest hotel: فندق سكليل
# sorong - nearest hotel: Marina Mamberamo
# arkadelphia - nearest hotel: Captain Henderson House
# broome - nearest hotel: No hotel found
# luanda - nearest hotel: Hotel Forum
# ponta delgada - nearest hotel: Hotel Talisman
# fort st. john - nearest hotel: Fort St. John Motor Inn
# mezhova - nearest hotel: No hotel found
# margate - nearest hotel: The Reading Rooms
# morant bay - nearest hotel: Morant Villas
# fada - nearest hotel: No hotel found
# portland - nearest hotel: the Hoxton
# funafuti - nearest hotel: Vaiaku Lagi Hotel
# berdigestyakh - nearest hotel: No hotel found
# pacific grove - nearest hotel: Pacific Grove Inn
# christchurch - nearest hotel: Ibis Hotel Christchurch
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# sandnessjoen - nearest hotel: Scandic Syv Søstre
# muana - nearest hotel: No hotel found
# bellegarde-sur-valserine - nearest hotel: Hermance
# happy valley-goose bay - nearest hotel: Hotel North Two
# tarauaca - nearest hotel: Hotel Estrela
# tofol - nearest hotel: Nautilus Resort
# tank - nearest hotel: No hotel found
# rajura - nearest hotel: No hotel found
# conceicao da barra - nearest hotel: Porto Marlin Hotel
# malango - nearest hotel: Madarana
# vadso - nearest hotel: Scandic Vadsø
# wellston - nearest hotel: No hotel found
# coxim - nearest hotel: Avendita
# oriximina - nearest hotel: No hotel found
# koniecpol - nearest hotel: No hotel found
# nadi - nearest hotel: President Hotel
# aksu - nearest hotel: Akesu Tianyuan International Hotel
# bentiu - nearest hotel: Peace Hotel
# lata - nearest hotel: Residencial Botânico
# caburan - nearest hotel: No hotel found
# tenenkou - nearest hotel: No hotel found
# evinayong - nearest hotel: No hotel found
# wurtulla - nearest hotel: Currimundi Hotel
# sale - nearest hotel: Le dawliz
# mount pearl - nearest hotel: Sandman Signature St. John's
# progreso - nearest hotel: Centro Vacacional Obrero CTM
# cristalina - nearest hotel: Goyás
# nagqu - nearest hotel: Naqu Hotel
# ewo - nearest hotel: No hotel found
# enniskillen - nearest hotel: The Enniskillen Hotel
# manali - nearest hotel: Vijay Park
# santa ana - nearest hotel: Holiday Inn Express
# miches - nearest hotel: Hôtel Atabey
# tocopilla - nearest hotel: hotel Isidora
# vernon - nearest hotel: Okanagan Royal Park Inn
# itanhem - nearest hotel: No hotel found
# gadzhiyevo - nearest hotel: Оазис
# princeville - nearest hotel: No hotel found
# naze - nearest hotel: ビジネス旅館畠山
# maralal - nearest hotel: Peacock Rest House
# ceeldheer - nearest hotel: No hotel found
# santa marta - nearest hotel: Casa Mita
# balqash - nearest hotel: Престиж
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# ishigaki - nearest hotel: アートホテル石垣島
# port hedland - nearest hotel: The Esplanade Hotel
# hanceville - nearest hotel: No hotel found
# mili - nearest hotel: No hotel found
# susuman - nearest hotel: No hotel found
# floro - nearest hotel: Comfort Hotel Victoria Florø
# saint-pierre - nearest hotel: Tropic Hotel
# sao tome - nearest hotel: Hotel Baia
# guarapari - nearest hotel: Osmar Hotel
# callao - nearest hotel: Casa Ronald
# znamenskoye - nearest hotel: No hotel found
# whakatane - nearest hotel: Whakatane Hotel
# basco - nearest hotel: Tawsen Hotel
# saldanha - nearest hotel: Hoedjesbaai
# yamada - nearest hotel: No hotel found
# licheng - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: Salles
# seydisehir - nearest hotel: sey-han hotel
# birstein - nearest hotel: Pension Schöne Aussicht
# les avirons - nearest hotel: Floralys
# agapovka - nearest hotel: No hotel found
# jamul - nearest hotel: No hotel found
# nyurba - nearest hotel: Марина
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# sinop - nearest hotel: No hotel found
# kamiiso - nearest hotel: 旅館やまに
# poronaysk - nearest hotel: No hotel found
# guiuan - nearest hotel: Addison Pension House
# baranchinskiy - nearest hotel: No hotel found
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# bulawayo - nearest hotel: Selboune Hotel
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# coronado - nearest hotel: Hotel Marisol Coronado
# alaghsas - nearest hotel: Hôtel Zagado
# codrington - nearest hotel: No hotel found
# zaozersk - nearest hotel: Северное сияние
# dolores - nearest hotel: Plaza Hotel
# del rio - nearest hotel: La Quinta Inn by Wyndham Del Rio
# pestovo - nearest hotel: No hotel found
# tvoroyri - nearest hotel: Hotel Tvøroyri
# prince rupert - nearest hotel: Crest Hotel
# zyryanovsk - nearest hotel: У Брилина
# hit - nearest hotel: No hotel found
# teknaf - nearest hotel: No hotel found
# el calafate - nearest hotel: Hostería Las Avutardas
# zholymbet - nearest hotel: No hotel found
# aykhal - nearest hotel: Уют
# okhotsk - nearest hotel: No hotel found
# cam pha mines - nearest hotel: Hai Yen Luxury Hotel
# riyadh - nearest hotel: White Palace Hotel
# priargunsk - nearest hotel: No hotel found
# azangaro - nearest hotel: Hotel Princess Jairito
# west bay - nearest hotel: Bonnie's Arch
# port augusta - nearest hotel: Hotel Commonwealth
# lewisburg - nearest hotel: No hotel found
# st. paul - nearest hotel: Crowne Plaza
# tasek glugor - nearest hotel: Seven Eight Nine Lunas Budget Hotel
# kozhevnikovo - nearest hotel: Вега
# sao vicente - nearest hotel: Pousada Vitória
# tyukalinsk - nearest hotel: No hotel found
# bandar-e anzali - nearest hotel: هتل فرهنگیان انزلی
#                 City Country      Lat       Lng  Humidity  \
# 0          ilulissat      GL  69.2167  -51.1000        76
# 1             bethel      US  41.3712  -73.4140        81
# 2         st. john's      CA  47.5649  -52.7093        82
# 3          adamstown      PN -25.0660 -130.1015        60
# 4          boguchany      RU  58.3814   97.4531        45
# ..               ...     ...      ...       ...       ...
# 546     tasek glugor      MY   5.4803  100.4985        79
# 547     kozhevnikovo      RU  56.2589   83.9714        41
# 548      sao vicente      BR -23.9631  -46.3919        26
# 549       tyukalinsk      RU  55.8732   72.1967        42
# 550  bandar-e anzali      IR  37.4727   49.4622        66
#
#                               Hotel Name
# 0      Best Western Plus Hotel Ilulissat
# 1                    Hampton Inn Danbury
# 2                              Alt Hotel
# 3                         No hotel found
# 4                                  Полет
# ..                                   ...
# 546  Seven Eight Nine Lunas Budget Hotel
# 547                                 Вега
# 548                      Pousada Vitória
# 549                       No hotel found
# 550                   هتل فرهنگیان انزلی
#
# [546 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

hotel_map_plot = hotel_df.hvplot.points(hover_cols=["Hotel Name", "Country"],
                                        x="Lng",
                                        y="Lat",
                                      geo = True,
                                      scale = 1,
                                      color = "City",
                                      alpha = 0.5,
                                      tiles = "OSM",
                                      frame_width = 700,
                                      frame_height = 500
                                    )

# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
